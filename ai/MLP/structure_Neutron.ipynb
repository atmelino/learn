# %% [markdown]
# ###  print out structures

# %%
import random
import numpy as np
from mycrograd_debug.engine_debug import Value
from mycrograd_debug.nn_debug import Neuron, Layer, MLP
from mycrograd_debug.drawviz_debug import draw_dot
np.random.seed(1337)
random.seed(1337)

# %%
# loss function
def loss(targets,outputs):
    total_loss = sum((yout - ygt) ** 2 for ygt, yout in zip(outputs, targets))
    return total_loss

# %% [markdown]
# #### Neuron

# %%
nin=3  #number of inputs
nout=1  #number of outputs

Value.value_counter=0

myNeuron=Neuron(nin)
print("number of inputs: ",nin)
print("Neuron: ",myNeuron)
print("weights: ",myNeuron.w)
print("b: ",myNeuron.b)
print("b type: ",myNeuron.b.type)
print("number of parameters ", len(myNeuron.parameters()))
print(myNeuron.parameters())

# xinumbers= np.random.randint(1,10, size=(nin))   # inputs
xinumbers=[1,2,3,4]
xi = [Value(x,type='i') for x in xinumbers]
print("inputs ", xi)

xtarget= np.random.randint(1,10, size=(nout))   # targets
print("targets ", xtarget)


#loss_Neuron=loss(myNeuron(xi),xtarget)
activation=myNeuron(xi)
print("number of Value objects created = ",Value.value_counter)

print("activation: ",activation)
activation.backward()
draw_dot(activation)
# Out:
# neuron nonlin is  False
# number of inputs:  3
# Neuron:  LinearNeuron(3)
# weights:  [Value(name=val1,type=w,data=0.1715747078045431, grad=0), Value(name=val2,type=w,data=-0.6686254326224383, grad=0), Value(name=val3,type=w,data=0.6487474938152629, grad=0)]
# b:  Value(name=val4,type=b,data=0, grad=0)
# b type:  b
# number of parameters  4
# [Value(name=val1,type=w,data=0.1715747078045431, grad=0), Value(name=val2,type=w,data=-0.6686254326224383, grad=0), Value(name=val3,type=w,data=0.6487474938152629, grad=0), Value(name=val4,type=b,data=0, grad=0)]
# inputs  [Value(name=val5,type=i,data=1, grad=0), Value(name=val6,type=i,data=2, grad=0), Value(name=val7,type=i,data=3, grad=0), Value(name=val8,type=i,data=4, grad=0)]
# targets  [3]
# number of Value objects created =  14
# activation:  Value(name=val14,type=a,data=0.780566324005455, grad=0)
