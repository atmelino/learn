# %% [markdown]
# https://github.com/tensorflow/tensorflow/issues/62963

# %% [markdown]
# up to tensorflow 2.20: error
#
# tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#
# tensorflow 2.21: no error

# %%
import tensorflow as tf
print(f"Tensor Flow Version: {tf.__version__}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775349691.844771  180259 pjrt_api.cc:96] PJRT_Api is set for device type gpu
# I0000 00:00:1775349691.848676  180259 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensor Flow Version: 2.22.0-dev20260404

# %%
import tensorflow as tf

range_ds = tf.data.Dataset.range(10)

for d in range_ds:
   print(d)
# Out:
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(3, shape=(), dtype=int64)
# tf.Tensor(4, shape=(), dtype=int64)
# tf.Tensor(5, shape=(), dtype=int64)
# tf.Tensor(6, shape=(), dtype=int64)
# tf.Tensor(7, shape=(), dtype=int64)
# tf.Tensor(8, shape=(), dtype=int64)
# tf.Tensor(9, shape=(), dtype=int64)
# I0000 00:00:1775349697.922852  180259 gpu_device.cc:2042] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22462 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:81:00.0, compute capability: 8.6
# I0000 00:00:1775349697.923620  180259 gpu_device.cc:2042] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22462 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6

# %% [markdown]
# https://github.com/tensorflow/tensorflow/issues/68593

# %%
import tensorflow as tf

def dataset_test():
 
    dataset = tf.data.Dataset.from_tensor_slices(["apple", "banana", "cherry"])
    # dataset = tf.data.TextLineDataset(["file1.txt", "file2.txt"]).range(10)             # same output
    # dataset = tf.data.TFRecordDataset(["file1.tfrecords", "file2.tfrecords"]).range(10) # same output
    # dataset = tf.data.Dataset.from_tensors([1,2,3]).range(10)                           # same output

    print(list(dataset.as_numpy_iterator()))

if __name__ == "__main__":
    dataset_test()
# Out:
# [b'apple', b'banana', b'cherry']
