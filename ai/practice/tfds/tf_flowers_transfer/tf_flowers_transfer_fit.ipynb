# %%
# based on https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_09_2_keras_xfer_cv.ipynb

import tensorflow_datasets as tfds
import tensorflow as tf
import logging, os
from tensorflow import keras
from tensorflow.keras import layers

BASE_PATH = "../../../../../local_data/practice/tfds/"
DATA_PATH = "../../../../../local_data/tfds/"
OUTPUT_PATH = BASE_PATH+"tf_flowers_transfer/"
os.system("mkdir -p " + OUTPUT_PATH)

train_dataset, validation_dataset = tfds.load(
    "tf_flowers",
    data_dir=DATA_PATH,
    split=["train[:40%]", "train[40%:50%]"],
    as_supervised=True,  # Include labels
)

num_train = tf.data.experimental.cardinality(train_dataset)
num_test = tf.data.experimental.cardinality(validation_dataset)

print(f"Number of training samples: {num_train}")
print(f"Number of validation samples: {num_test}")
# Out:
# 2025-07-20 19:57:22.522812: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-20 19:57:22.522845: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-20 19:57:22.523684: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-20 19:57:22.528346: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-20 19:57:24.066629: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-20 19:57:24.066914: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-20 19:57:24.125381: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-20 19:57:24.125650: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-20 19:57:24.125885: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-20 19:57:24.126102: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/data/util/structure.py:105, in normalize_element(element, element_signature)
#     104   if spec is None:
# --> 105     spec = type_spec_from_value(t, use_fallback=False)
#     106 except TypeError:
#     107   # TypeError indicates it was not possible to compute a `TypeSpec` for
#     108   # the value. As a fallback try converting the value to a tensor.
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/data/util/structure.py:514, in type_spec_from_value(element, use_fallback)
#     511     logging.vlog(
#     512         3, "Failed to convert %r to tensor: %s" % (type(element).__name__, e))
# --> 514 raise TypeError("Could not build a `TypeSpec` for {} with type {}".format(
#     515     element,
#     516     type(element).__name__))
#
# TypeError: Could not build a `TypeSpec` for ['../../../../../local_data/tfds/tf_flowers/3.0.1/tf_flowers-train.tfrecord-00000-of-00002'] with type list
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 14
#      11 OUTPUT_PATH = BASE_PATH+"tf_flowers_transfer/"
#      12 os.system("mkdir -p " + OUTPUT_PATH)
# ---> 14 train_dataset, validation_dataset = tfds.load(
#      15     "tf_flowers",
#      16     data_dir=DATA_PATH,
#      17     split=["train[:40%]", "train[40%:50%]"],
#      18     as_supervised=True,  # Include labels
#      19 )
#      21 num_train = tf.data.experimental.cardinality(train_dataset)
#      22 num_test = tf.data.experimental.cardinality(validation_dataset)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/logging/__init__.py:169, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     167 metadata = self._start_call()
#     168 try:
# --> 169   return function(*args, **kwargs)
#     170 except Exception:
#     171   metadata.mark_error()
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/load.py:629, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     626 as_dataset_kwargs.setdefault('shuffle_files', shuffle_files)
#     627 as_dataset_kwargs.setdefault('read_config', read_config)
# --> 629 ds = dbuilder.as_dataset(**as_dataset_kwargs)
#     630 if with_info:
#     631   return ds, dbuilder.info
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/logging/__init__.py:169, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     167 metadata = self._start_call()
#     168 try:
# --> 169   return function(*args, **kwargs)
#     170 except Exception:
#     171   metadata.mark_error()
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py:781, in DatasetBuilder.as_dataset(self, split, batch_size, shuffle_files, decoders, read_config, as_supervised)
#     772 # Create a dataset for each of the given splits
#     773 build_single_dataset = functools.partial(
#     774     self._build_single_dataset,
#     775     shuffle_files=shuffle_files,
#    (...)
#     779     as_supervised=as_supervised,
#     780 )
# --> 781 all_ds = tree_utils.map_structure(build_single_dataset, split)
#     782 return all_ds
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tree/__init__.py:435, in map_structure(func, *structures, **kwargs)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tree/__init__.py:435, in <listcomp>(.0)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py:799, in DatasetBuilder._build_single_dataset(self, split, batch_size, shuffle_files, decoders, read_config, as_supervised)
#     796   batch_size = self.info.splits.total_num_examples or sys.maxsize
#     798 # Build base dataset
# --> 799 ds = self._as_dataset(
#     800     split=split,
#     801     shuffle_files=shuffle_files,
#     802     decoders=decoders,
#     803     read_config=read_config,
#     804 )
#     805 # Auto-cache small datasets which are small enough to fit in memory.
#     806 if self._should_cache_ds(
#     807     split=split, shuffle_files=shuffle_files, read_config=read_config
#     808 ):
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/dataset_builder.py:1252, in FileReaderBuilder._as_dataset(self, split, decoders, read_config, shuffle_files)
#    1246 reader = reader_lib.Reader(
#    1247     self._data_dir,
#    1248     example_specs=example_specs,
#    1249     file_format=self.info.file_format,
#    1250 )
#    1251 decode_fn = functools.partial(features.decode_example, decoders=decoders)
# -> 1252 return reader.read(
#    1253     instructions=split,
#    1254     split_infos=self.info.splits.values(),
#    1255     decode_fn=decode_fn,
#    1256     read_config=read_config,
#    1257     shuffle_files=shuffle_files,
#    1258     disable_shuffling=self.info.disable_shuffling,
#    1259 )
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/reader.py:413, in Reader.read(self, instructions, split_infos, read_config, shuffle_files, disable_shuffling, decode_fn)
#     404   file_instructions = splits_dict[instruction].file_instructions
#     405   return self.read_files(
#     406       file_instructions,
#     407       read_config=read_config,
#    (...)
#     410       decode_fn=decode_fn,
#     411   )
# --> 413 return tree_utils.map_structure(_read_instruction_to_ds, instructions)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tree/__init__.py:435, in map_structure(func, *structures, **kwargs)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tree/__init__.py:435, in <listcomp>(.0)
#     432 for other in structures[1:]:
#     433   assert_same_structure(structures[0], other, check_types=check_types)
#     434 return unflatten_as(structures[0],
# --> 435                     [func(*args) for args in zip(*map(flatten, structures))])
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/reader.py:405, in Reader.read.<locals>._read_instruction_to_ds(instruction)
#     403 def _read_instruction_to_ds(instruction):
#     404   file_instructions = splits_dict[instruction].file_instructions
# --> 405   return self.read_files(
#     406       file_instructions,
#     407       read_config=read_config,
#     408       shuffle_files=shuffle_files,
#     409       disable_shuffling=disable_shuffling,
#     410       decode_fn=decode_fn,
#     411   )
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/reader.py:445, in Reader.read_files(self, file_instructions, read_config, shuffle_files, disable_shuffling, decode_fn)
#     442   raise ValueError(msg)
#     444 # Read serialized example (eventually with `tfds_id`)
# --> 445 ds = _read_files(
#     446     file_instructions=file_instructions,
#     447     read_config=read_config,
#     448     shuffle_files=shuffle_files,
#     449     disable_shuffling=disable_shuffling,
#     450     file_format=self._file_format,
#     451 )
#     453 # Parse and decode
#     454 def parse_and_decode(ex: Tensor) -> TreeDict[Tensor]:
#     455   # TODO(pierrot): `parse_example` uses
#     456   # `tf.io.parse_single_example`. It might be faster to use `parse_example`,
#     457   # after batching.
#     458   # https://www.tensorflow.org/api_docs/python/tf/io/parse_example
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow_datasets/core/reader.py:254, in _read_files(file_instructions, read_config, shuffle_files, disable_shuffling, file_format)
#     246 if disable_shuffling:
#     247   _verify_read_config_for_ordered_dataset(
#     248       read_config,
#     249       interleave_cycle_length=cycle_length,
#     250       shuffle_files=shuffle_files,
#     251   )
# --> 254 instruction_ds = tf.data.Dataset.from_tensor_slices(tensor_inputs)
#     256 # On distributed environments, we can shard per-file if a
#     257 # `tf.distribute.InputContext` object is provided (e.g. from
#     258 # `experimental_distribute_datasets_from_function`)
#     259 if read_config.input_context:
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:825, in DatasetV2.from_tensor_slices(tensors, name)
#     821 # Loaded lazily due to a circular dependency (dataset_ops ->
#     822 # from_tensor_slices_op -> dataset_ops).
#     823 # pylint: disable=g-import-not-at-top,protected-access
#     824 from tensorflow.python.data.ops import from_tensor_slices_op
# --> 825 return from_tensor_slices_op._from_tensor_slices(tensors, name)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py:25, in _from_tensor_slices(tensors, name)
#      24 def _from_tensor_slices(tensors, name=None):
# ---> 25   return _TensorSliceDataset(tensors, name=name)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/data/ops/from_tensor_slices_op.py:33, in _TensorSliceDataset.__init__(self, element, is_files, name)
#      31 def __init__(self, element, is_files=False, name=None):
#      32   """See `Dataset.from_tensor_slices` for details."""
# ---> 33   element = structure.normalize_element(element)
#      34   batched_spec = structure.type_spec_from_value(element)
#      35   self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/data/util/structure.py:110, in normalize_element(element, element_signature)
#     105     spec = type_spec_from_value(t, use_fallback=False)
#     106 except TypeError:
#     107   # TypeError indicates it was not possible to compute a `TypeSpec` for
#     108   # the value. As a fallback try converting the value to a tensor.
#     109   normalized_components.append(
# --> 110       ops.convert_to_tensor(t, name="component_%d" % i))
#     111 else:
#     112   # To avoid a circular dependency between dataset_ops and structure,
#     113   # we check the class name instead of using `isinstance`.
#     114   if spec.__class__.__name__ == "DatasetSpec":
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:696, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     694 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     695 preferred_dtype = preferred_dtype or dtype_hint
# --> 696 return tensor_conversion_registry.convert(
#     697     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     698 )
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:335, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     332 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     333                                          as_ref=False):
#     334   _ = as_ref
# --> 335   return constant(v, dtype=dtype, name=name)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:271, in constant(value, dtype, shape, name)
#     172 @tf_export("constant", v1=[])
#     173 def constant(
#     174     value, dtype=None, shape=None, name="Const"
#     175 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     176   """Creates a constant tensor from a tensor-like object.
#     177
#     178   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:284, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     282     with trace.Trace("tf.constant"):
#     283       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 284   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     286 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     287     value, dtype, shape, name, verify_shape, allow_broadcast
#     288 )
#     289 return const_tensor
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:296, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     292 def _constant_eager_impl(
#     293     ctx, value, dtype, shape, verify_shape
#     294 ) -> ops._EagerTensorBase:
#     295   """Creates a constant on the current device."""
# --> 296   t = convert_to_eager_tensor(value, ctx, dtype)
#     297   if shape is None:
#     298     return t
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100   except AttributeError:
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
# --> 102 ctx.ensure_initialized()
#     103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# File /media/data/miniconda3/envs/jh_class/lib/python3.10/site-packages/tensorflow/python/eager/context.py:603, in Context.ensure_initialized(self)
#     600   pywrap_tfe.TFE_ContextOptionsSetRunEagerOpAsFunction(opts, True)
#     601   pywrap_tfe.TFE_ContextOptionsSetJitCompileRewrite(
#     602       opts, self._jit_compile_rewrite)
# --> 603   context_handle = pywrap_tfe.TFE_NewContext(opts)
#     604 finally:
#     605   pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# RuntimeError: Bad StatusOr access: INTERNAL: failed initializing StreamExecutor for CUDA device ordinal 0: INTERNAL: failed call to cuDevicePrimaryCtxRetain: CUDA_ERROR_OUT_OF_MEMORY: out of memory; total memory reported: 25438126080

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 10))
# for i, (image, label) in enumerate(train_dataset.take(9)):
#     ax = plt.subplot(3, 3, i + 1)
#     plt.imshow(image)
#     plt.title(int(label))
#     plt.axis("off")

# %%
size = (150, 150)

train_dataset = train_dataset.map(lambda x, y: (tf.image.resize(x, size), y))
validation_dataset = validation_dataset.map(lambda x, y: \
                                  (tf.image.resize(x, size), y))

batch_size = 32

train_dataset = train_dataset.cache().batch(batch_size).prefetch(buffer_size=10)
validation_dataset = validation_dataset.cache() \
    .batch(batch_size).prefetch(buffer_size=10)

data_augmentation = keras.Sequential(
    [layers.RandomFlip("horizontal"), layers.RandomRotation(0.1),]
)

# %%
base_model = keras.applications.Xception(
    weights="imagenet",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False,
)  # Do not include the ImageNet classifier at the top.

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

# Pre-trained Xception weights requires that input be scaled
# from (0, 255) to a range of (-1., +1.), the rescaling layer
# outputs: `(inputs * scale) + offset`
scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = scale_layer(x)

# The base model contains batchnorm layers. 
# We want to keep them in inference mode
# when we unfreeze the base model for fine-tuning, 
# so we make sure that the
# base_model is running in inference mode here.
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(5)(x)
model = keras.Model(inputs, outputs)

model.summary()

# %%
model.compile(
    # optimizer=tf.keras.optimizers.Adam(0.001),
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
epochs = 2
history =model.fit(train_dataset, epochs=epochs,validation_data=validation_dataset)

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'sparse_categorical_accuracy' ]
val_acc  = history.history[ 'val_sparse_categorical_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs_plot   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs_plot,     acc , label="training accuracy")
plt.plot  ( epochs_plot, val_acc, label="validation accuracy" )
plt.title ('Training and validation accuracy')
plt.legend(loc="upper left")
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs_plot,     loss , label="training loss")
plt.plot  ( epochs_plot, val_loss , label="validation loss" )
plt.legend(loc="upper left")
plt.title ('Training and validation loss'   )
