# %%
import matplotlib.pyplot as plt
from PIL import Image
import io

plt.plot([1, 2])
img_buf = io.BytesIO()
plt.savefig(img_buf, format='png')
im = Image.open(img_buf)
im.show(title="My Image")
# Out:
# Gtk-Message: 17:27:14.137: Failed to load module "canberra-gtk-module"
# Gtk-Message: 17:27:15.266: Failed to load module "canberra-gtk-module"
